# %%
# %matplotlib inline 
import matplotlib.pylab
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(600, 3), index = pd.date_range('7/1/2016', freq = 'S', periods = 600), columns = ['A', 'B', 'C'])

# %%
r = df.rolling(window = 10)

df.plot(style = 'k--')
r.mean().plot(style = 'k')
# Out:
# <AxesSubplot:>

# %%
# can also easily plot a rolling average per column
df = pd.DataFrame(np.random.randn(1000, 4), index = pd.date_range('6/6/16', periods = 1000), columns = ['A', 'B', 'C', 'D'])

# %%
df.head()
# Out:
#                    A         B         C         D
# 2016-06-06 -0.437467 -0.263599 -0.648846 -0.244092
# 2016-06-07 -0.702742 -0.851957 -0.600407  0.262433
# 2016-06-08  0.542220 -0.372613 -0.535752  1.037496
# 2016-06-09  0.989983  0.469522 -0.506634  0.234058
# 2016-06-10 -0.710540  0.230598 -0.046371 -0.402398

# %%
df = df.cumsum()
df.rolling(window = 50).sum().plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
# What about a custom function?
df.rolling(window = 10).apply(lambda x: np.fabs(x - x.mean()).mean())
# Out:
#                    A         B         C         D
# 2016-06-06       NaN       NaN       NaN       NaN
# 2016-06-07       NaN       NaN       NaN       NaN
# 2016-06-08       NaN       NaN       NaN       NaN
# 2016-06-09       NaN       NaN       NaN       NaN
# 2016-06-10       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...
# 2019-02-26  1.436121  0.477432  1.425114  0.567776
# 2019-02-27  1.806312  0.509156  1.346401  0.597066
# 2019-02-28  2.019019  0.589277  1.156795  0.698628
# 2019-03-01  2.170753  0.720077  0.634326  0.849797
# 2019-03-02  2.138244  0.900644  0.387625  0.802354
#
# [1000 rows x 4 columns]

# %%
df.expanding(min_periods = 1).mean()[1:5]
# Out:
#                    A         B         C         D
# 2016-06-07 -0.788838 -0.689577 -0.949049 -0.112876
# 2016-06-08 -0.725222 -0.955774 -1.227701  0.276695
# 2016-06-09 -0.445918 -0.971492 -1.493685  0.529995
# 2016-06-10 -0.420444 -0.934804 -1.662550  0.601495
